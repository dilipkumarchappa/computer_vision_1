# %% [markdown]
# ### Download Flowers Dataset

# %%
#You can download the data manually as well instead of using 'wget'
# !wget http://download.tensorflow.org/example_images/flower_photos.tgz --quiet

# %%
#Read the dataset
import tarfile
dataset = tarfile.open('flower_photos.tgz')

# %%
#We will build a pandas dataset
import pandas as pd
df = pd.DataFrame(columns=['class','dir','image_file'])

# %%
#Run through tarfile members 
for name in dataset.getnames():
    
    tar_mem = dataset.getmember(name)
    
    #Check if it is a file
    if(tar_mem.isfile() and name.endswith('.jpg')):
        #Build directory and class info
        im_dir = name[0:name.rfind('/')]
        im_class = im_dir[im_dir.rfind('/')+1:]
        #Add record to the dataframe
        df.loc[df.shape[0]] = [im_class, im_dir, name]

# %%
#extract data
dataset.extractall(path='data/')

# %% [markdown]
# Create Training & Test dataset

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
train_df.to_csv('data/flower_photos/train.csv',index=False)
test_df.to_csv('data/flower_photos/test.csv', index=False)

# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf
tf.reset_default_graph()
tf.set_random_seed(42)

# %% [markdown]
# ### Read training and test data

# %%
import pandas as pd
train_df = pd.read_csv('data/flower_photos/train.csv')
test_df = pd.read_csv('data/flower_photos/test.csv')

# %%
#Get class names
class_names = train_df['class'].unique().tolist()
print('Flower classes: ', class_names)
# Out:
# Flower classes:  ['tulips', 'daisy', 'sunflowers', 'dandelion', 'roses']

# %%
#Define some parameters
img_size = 60
img_depth = 3

# %% [markdown]
# ### Build batch generator

# %%
import numpy as np

# %%
def batch_generator(df, batchsize=32, train_mode=True):   
    
    img_generator= tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20,
                                                                   width_shift_range=0.2,
                                                                   height_shift_range=0.2,
                                                                   horizontal_flip=True)
    
    while True:       
        
        
        #Generate random numbers to pick images from dataset
        batch_nums = np.random.randint(0,df.shape[0],batchsize)
        
        #Initialize batch images array
        batch_images = np.zeros((batchsize,img_size, img_size,img_depth))
        
        #Initiate batch label array
        batch_labels = np.zeros((batchsize, len(class_names)))
        
        for i in range(batchsize):
            
            #Load image
            flower_image =  tf.keras.preprocessing.image.load_img('data/' + 
                                                                  df.loc[batch_nums[i]]['image_file'],
                                                                  target_size=(img_size, img_size))
            #Convert to array
            flower_image = tf.keras.preprocessing.image.img_to_array(flower_image)
            
            if(train_mode):
                #Apply transform
                flower_image =  img_generator.random_transform(flower_image)
            
            
            #Get the class
            img_class = df.loc[batch_nums[i]]['class']
            #Conver class to number
            img_class = class_names.index(img_class)
            #Convert class to one hot encoding
            img_class = tf.keras.utils.to_categorical(img_class, num_classes=len(class_names))
            
            #Update batch images and class arrays
            batch_images[i] = flower_image
            batch_labels[i] = img_class        
        
        yield batch_images, batch_labels

# %% [markdown]
# ### Build CNN Model

# %%
#Clear out session 
tf.keras.backend.clear_session()

#Initialize model, reshape & normalize data
model = tf.keras.models.Sequential()

#Add Layers
model.add(tf.keras.layers.BatchNormalization(input_shape=(img_size,img_size,3,)))
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train the model

# %%
#Create train and test generator
batchsize = 64
train_generator = batch_generator(train_df, batchsize=batchsize) #batchsize can be changed
test_generator = batch_generator(test_df, batchsize=batchsize)

# %%
model.fit_generator(train_generator, 
                          epochs=50,
                          steps_per_epoch= train_df.shape[0]//batchsize,
                          validation_data=test_generator,
                          validation_steps = test_df.shape[0]//batchsize)
# Out:
# Epoch 1/50
# 45/45 [==============================] - 18s 395ms/step - loss: 2.1043 - acc: 0.3497 - val_loss: 1.5830 - val_acc: 0.3267
# Epoch 2/50
# 45/45 [==============================] - 13s 291ms/step - loss: 1.2070 - acc: 0.5052 - val_loss: 1.1653 - val_acc: 0.5412
# Epoch 3/50
# 45/45 [==============================] - 13s 293ms/step - loss: 1.1552 - acc: 0.5330 - val_loss: 1.0723 - val_acc: 0.5739
# Epoch 4/50
# 45/45 [==============================] - 13s 289ms/step - loss: 1.1111 - acc: 0.5583 - val_loss: 0.9758 - val_acc: 0.5923
# Epoch 5/50
# 45/45 [==============================] - 14s 301ms/step - loss: 1.0145 - acc: 0.6156 - val_loss: 0.9635 - val_acc: 0.6264
# Epoch 6/50
# 45/45 [==============================] - 13s 295ms/step - loss: 0.9459 - acc: 0.6326 - val_loss: 0.9091 - val_acc: 0.6619
# Epoch 7/50
# 45/45 [==============================] - 13s 284ms/step - loss: 0.9340 - acc: 0.6403 - val_loss: 0.8305 - val_acc: 0.6875
# Epoch 8/50
# 45/45 [==============================] - 13s 289ms/step - loss: 0.9056 - acc: 0.6559 - val_loss: 0.8602 - val_acc: 0.6548
# Epoch 9/50
# 45/45 [==============================] - 13s 297ms/step - loss: 0.9208 - acc: 0.6549 - val_loss: 0.8858 - val_acc: 0.6676
# Epoch 10/50
# 45/45 [==============================] - 13s 290ms/step - loss: 0.8507 - acc: 0.6809 - val_loss: 0.8598 - val_acc: 0.6506
# Epoch 11/50
# 45/45 [==============================] - 13s 293ms/step - loss: 0.8052 - acc: 0.7024 - val_loss: 0.7812 - val_acc: 0.7230
# Epoch 12/50
# 45/45 [==============================] - 13s 290ms/step - loss: 0.8129 - acc: 0.6913 - val_loss: 0.7819 - val_acc: 0.7188
# Epoch 13/50
# 45/45 [==============================] - 13s 282ms/step - loss: 0.8376 - acc: 0.6812 - val_loss: 0.7546 - val_acc: 0.7017
# Epoch 14/50
# 45/45 [==============================] - 13s 281ms/step - loss: 0.7985 - acc: 0.6924 - val_loss: 0.8263 - val_acc: 0.6804
# Epoch 15/50
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7885 - acc: 0.7087 - val_loss: 0.7485 - val_acc: 0.6960
# Epoch 16/50
# 45/45 [==============================] - 13s 281ms/step - loss: 0.7460 - acc: 0.7111 - val_loss: 0.7271 - val_acc: 0.7301
# Epoch 17/50
# 45/45 [==============================] - 13s 279ms/step - loss: 0.7382 - acc: 0.7181 - val_loss: 0.7801 - val_acc: 0.6960
# Epoch 18/50
# 45/45 [==============================] - 12s 277ms/step - loss: 0.7419 - acc: 0.7104 - val_loss: 0.8001 - val_acc: 0.7273
# Epoch 19/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.7554 - acc: 0.7109Epoch 20/50
# 45/45 [==============================] - 13s 279ms/step - loss: 0.7007 - acc: 0.7410 - val_loss: 0.7824 - val_acc: 0.7131
# Epoch 21/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.6952 - acc: 0.7385 - val_loss: 0.7839 - val_acc: 0.6889
# Epoch 22/50
# 45/45 [==============================] - 13s 278ms/step - loss: 0.7105 - acc: 0.7312 - val_loss: 0.7128 - val_acc: 0.7443
# Epoch 23/50
# 45/45 [==============================] - 12s 270ms/step - loss: 0.6496 - acc: 0.7559 - val_loss: 0.7498 - val_acc: 0.7344
# Epoch 24/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.6707 - acc: 0.7497 - val_loss: 0.7330 - val_acc: 0.7244
# Epoch 25/50
# 45/45 [==============================] - 12s 271ms/step - loss: 0.6629 - acc: 0.7368 - val_loss: 0.7650 - val_acc: 0.7045
# Epoch 26/50
# 45/45 [==============================] - 12s 269ms/step - loss: 0.6570 - acc: 0.7559 - val_loss: 0.7356 - val_acc: 0.7401
# Epoch 27/50
# 45/45 [==============================] - 12s 270ms/step - loss: 0.6589 - acc: 0.7628 - val_loss: 0.7947 - val_acc: 0.7202
# Epoch 28/50
# 45/45 [==============================] - 12s 275ms/step - loss: 0.6353 - acc: 0.7608 - val_loss: 0.7634 - val_acc: 0.7259
# Epoch 29/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.6420 - acc: 0.7556 - val_loss: 0.7785 - val_acc: 0.7102
# Epoch 30/50
# 45/45 [==============================] - 12s 274ms/step - loss: 0.6380 - acc: 0.7615 - val_loss: 0.7000 - val_acc: 0.7472
# Epoch 31/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.6462 - acc: 0.7559 - val_loss: 0.7701 - val_acc: 0.7386
# Epoch 32/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.6229 - acc: 0.7608 - val_loss: 0.7136 - val_acc: 0.7358
# Epoch 33/50
# 45/45 [==============================] - 12s 275ms/step - loss: 0.6097 - acc: 0.7681 - val_loss: 0.6899 - val_acc: 0.7443
# Epoch 34/50
# 45/45 [==============================] - 13s 279ms/step - loss: 0.5805 - acc: 0.7802 - val_loss: 0.7862 - val_acc: 0.7372
# Epoch 35/50
# 45/45 [==============================] - 12s 277ms/step - loss: 0.6127 - acc: 0.7670 - val_loss: 0.7986 - val_acc: 0.7216
# Epoch 36/50
# 45/45 [==============================] - 12s 277ms/step - loss: 0.6246 - acc: 0.7653 - val_loss: 0.7154 - val_acc: 0.7628
# Epoch 37/50
# 45/45 [==============================] - 13s 278ms/step - loss: 0.6145 - acc: 0.7594 - val_loss: 0.7319 - val_acc: 0.7344
# Epoch 38/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.6189 - acc: 0.7712 - val_loss: 0.7018 - val_acc: 0.7415
# Epoch 39/50
# 45/45 [==============================] - 13s 279ms/step - loss: 0.5890 - acc: 0.7740 - val_loss: 0.7045 - val_acc: 0.7557
# Epoch 40/50
# 45/45 [==============================] - 13s 282ms/step - loss: 0.5906 - acc: 0.7788 - val_loss: 0.7423 - val_acc: 0.7159
# Epoch 41/50
# 45/45 [==============================] - 13s 281ms/step - loss: 0.5878 - acc: 0.7701 - val_loss: 0.7552 - val_acc: 0.7259
# Epoch 42/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.5859 - acc: 0.7719 - val_loss: 0.8079 - val_acc: 0.7116
# Epoch 43/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.5909 - acc: 0.7806 - val_loss: 0.7043 - val_acc: 0.7358
# Epoch 44/50
# 45/45 [==============================] - 13s 278ms/step - loss: 0.5747 - acc: 0.7878 - val_loss: 0.7567 - val_acc: 0.7401
# Epoch 45/50
# 45/45 [==============================] - 12s 275ms/step - loss: 0.5441 - acc: 0.7962 - val_loss: 0.7965 - val_acc: 0.7344
# Epoch 46/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.5724 - acc: 0.7844 - val_loss: 0.7054 - val_acc: 0.7571
# Epoch 47/50
# 14/45 [========>.....................] - ETA: 2s - loss: 0.5659 - acc: 0.7679
